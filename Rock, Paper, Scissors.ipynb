# %% [markdown]
# # 1

# %%
import random

input("Welcome to Rock, Paper, Scissors! Press Enter to start.")
print()
users_wins = 0
computers_wins = 0

choices = ["rock", "paper", "scissors"]

while True:
  random_index = random.randint(0,2)
  cpu_choice = choices[random_index]

  user_choice = input("Rock, Paper, or Scissors? ").lower()
  while user_choice not in choices:
    user_choice = input("That is not a valid choice. Please try again: ").lower()

  print()
  print("Your choice:", user_choice)
  print("Computer's choice:", cpu_choice)
  print()

  if user_choice == 'rock':
    if cpu_choice == 'rock':
      print("it's a tie!")
    elif cpu_choice == 'scissors':
        print("You win!")
        users_wins+=1
    elif cpu_choice == 'paper':
        print("You lose!")
        computers_wins+=1
    elif user_choice == 'paper':
      if cpu_choice == 'paper':
        print("it's a tie!")
      elif cpu_choice == 'rock':
        print("You win!")
        users_wins+=1
      elif cpu_choice == 'scissors':
        print("You lose!")
        computer_wins+=1
    elif user_choice == 'scissors':
      if cpu_choice == 'scissors':
        print("it's a tie!")
      elif cpu_choice == 'paper':
        print("You win!")
        users_wins+=1
      elif cpu_choice == 'rock':
        print("You lose!")
        computer_wins+=1

  print()
  print("You have "+str(users_wins)+" wins")
  print("The computer has "+str(computers_wins)+" wins")
  print()

  repeat = input("Play again? (Y/N) ").lower()
  while repeat not in ['y', 'n']:
    repeat = input("That is not a valid choice. Please try again: ").lower()

  if repeat == 'n':
    print("Bye bye")
    break

  print("\n--------------------------\n")

# %% [markdown]
# # 2

# %% [markdown]
# ### Mendefinisikan variabel yang dibutuhkan

# %%
import random
import numpy as np

user_wins = 0
computer_wins = 0
choices = ["rock", "paper", "scissors"]

usr_history = [0, 1]

# %% [markdown]
# ### Mendefinisikan fungsi

# %%
def get_bot_choice(usr_choice):
    prob = (sum( usr_history ) / len( usr_history ))/2
    bot_prediction = np.random.binomial(2, prob, 1)[0]
    usr_history.append(usr_choice)

    bot_choice = bot_prediction - 1
    if bot_choice < 0:
        bot_choice = 2
    return bot_choice

# %%
while True:
    user_choice = input("Rock, Paper, or Scissors? ").lower()
    
    while user_choice not in choices:
        user_choice = input("That is not a valid choice. Please try again: ").lower()
        
        
    random_index = get_bot_choice(choices.index('scissors'))
    cpu_choice = choices[random_index]

    print()
    print("Your choice:", user_choice)
    print("Computer's choice:", cpu_choice)
    print()

    if user_choice == 'rock':
        if cpu_choice == 'rock':
            print("It's a tie!")
        elif cpu_choice == 'scissors':
            print("You win!")
            user_wins+=1
        elif cpu_choice == 'paper':
            print("You lose!")
            computer_wins+=1
    elif user_choice == 'paper':
        if cpu_choice == 'paper':
            print("It's a tie!")
        elif cpu_choice == 'rock':
            print("You win!")
            user_wins+=1
        elif cpu_choice == 'scissors':
            print("You lose!")
            computer_wins+=1
    elif user_choice == 'scissors':
        if cpu_choice == 'scissors':
            print("It's a tie!")
        elif cpu_choice == 'paper':
            print("You win!")
            user_wins+=1
        elif cpu_choice == 'rock':
            print("You lose!")
            computer_wins+=1

    print()
    print("You have "+str(user_wins)+" wins")
    print("The computer has "+str(computer_wins)+" wins")
    print()

    repeat = input("Play again? (Y/N) ").lower()
    while repeat not in ['y', 'n']:
        repeat = input("That is not a valid choice. Please try again: ").lower()

    if repeat == 'n':
        print("Bye bye")   
        break

    print("\n----------------------------\n")
# Out:
# Rock, Paper, or Scissors? paper
#
# Your choice: paper
# Computer's choice: paper
#
# It's a tie!
#
# You have 2 wins
# The computer has 1 wins
#
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? asa
# That is not a valid choice. Please try again: y
# That is not a valid choice. Please try again: n
# That is not a valid choice. Please try again: paper
#
# Your choice: paper
# Computer's choice: scissors
#
# You lose!
#
# You have 2 wins
# The computer has 2 wins
#
# Play again? (Y/N) y
#
# ----------------------------
#
# Rock, Paper, or Scissors? adsadsd

# %%
import pandas as pd

# %% [markdown]
# # Data Jumlah Penduduk Berdasarkan Hubungan Status Dalam Keluarga Per Kelurahan Tahun 2019

# %%
df = pd.DataFrame(pd.read_csv('./dataset/data-jumlah-penduduk-berdasarkan-hubungan-status-dalam-keluarga-per-kelurahan-tahun-2019.csv'))
df
# Out:
#       tahun         nama_provinsi         nama_kabupaten  \
# 0      2019  PROVINSI DKI JAKARTA  ADM. KEPULAUAN SERIBU
# 1      2019  PROVINSI DKI JAKARTA  ADM. KEPULAUAN SERIBU
# 2      2019  PROVINSI DKI JAKARTA  ADM. KEPULAUAN SERIBU
# 3      2019  PROVINSI DKI JAKARTA  ADM. KEPULAUAN SERIBU
# 4      2019  PROVINSI DKI JAKARTA  ADM. KEPULAUAN SERIBU
# ...     ...                   ...                    ...
# 2703   2019  PROVINSI DKI JAKARTA          JAKARTA TIMUR
# 2704   2019  PROVINSI DKI JAKARTA          JAKARTA TIMUR
# 2705   2019  PROVINSI DKI JAKARTA          JAKARTA TIMUR
# 2706   2019  PROVINSI DKI JAKARTA          JAKARTA TIMUR
# 2707   2019  PROVINSI DKI JAKARTA          JAKARTA TIMUR
#
#               nama_kecamatan  nama_kelurahan status_dalam_keluarga  jumlah
# 0     KEPULAUAN SERIBU UTARA  PULAU PANGGANG                  Anak    3244
# 1     KEPULAUAN SERIBU UTARA  PULAU PANGGANG                  Cucu      26
# ...

# %%
df.describe()
# Out:
#         tahun        jumlah
# count  2708.0   2708.000000
# mean   2019.0   4083.805022
# std       0.0   7823.768043
# min    2019.0      1.000000
# 25%    2019.0     22.000000
# 50%    2019.0    201.000000
# 75%    2019.0   4940.000000
# max    2019.0  73061.000000

# %%
df = pd.DataFrame(pd.read_csv('./dataset/data-jumlah-penduduk-berdasarkan-pekerjaan-per-kelurahan-tahun-2018.csv'))
df
# Out:
#        tahun nama_provinsi         nama_kabupaten          nama_kecamatan  \
# 0       2018   DKI Jakarta  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 1       2018   DKI Jakarta  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 2       2018   DKI Jakarta  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 3       2018   DKI Jakarta  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 4       2018   DKI Jakarta  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# ...      ...           ...                    ...                     ...
# 11503   2018   DKI Jakarta          JAKARTA TIMUR                CIPAYUNG
# 11504   2018   DKI Jakarta          JAKARTA TIMUR                CIPAYUNG
# 11505   2018   DKI Jakarta          JAKARTA TIMUR                CIPAYUNG
# 11506   2018   DKI Jakarta          JAKARTA TIMUR                CIPAYUNG
# 11507   2018   DKI Jakarta          JAKARTA TIMUR                CIPAYUNG
#
#        nama_kelurahan       jenis_pekerajaan  jumlah
# ...

# %%
df.describe()
# Out:
#         tahun        jumlah
# count  2708.0   2708.000000
# mean   2019.0   4083.805022
# std       0.0   7823.768043
# min    2019.0      1.000000
# 25%    2019.0     22.000000
# 50%    2019.0    201.000000
# 75%    2019.0   4940.000000
# max    2019.0  73061.000000

# %%
df = pd.DataFrame(pd.read_csv('./dataset/data-seluruh-ruang-terbuka-hijau-di-provinsi-dki-jakarta.csv'))
df
# Out:
#        kodifikasi                            nama  \
# 0        15010008  Taman Hutan Kota Kampung Sawah
# 1        15010005     Taman Medan Merdeka (Monas)
# 2        15010001                   Taman Menteng
# 3        15010007                  Taman Suropati
# 4        15010006               Taman Situlembang
# ...           ...                             ...
# 3038  87310107004                     Pulau Karya
# 3039  87310107005            Pulau Harapan/Kelapa
# 3040  87310108002                   Pulau Lancang
# 3041  87310108001                    Pulau Tidung
# 3042  87310108003               Pulau Untung Jawa
#
#                                  lokasi           kotamadya   kecamatan  \
# 0      Kampung Sawah (sisi Tol Tomang)       Jakarta Barat    Palmerah
# 1                     Jl. Silang Monas       Jakarta Pusat      Gambir
# 2                 Jl. HOS Cokroaminoto       Jakarta Pusat     Menteng
# 3                  Jl. Untung Suropati       Jakarta Pusat     Menteng
# ...

# %%
df.describe()
# Out:
#          kodifikasi           luas
# count  3.043000e+03    3043.000000
# mean   2.770975e+09    5302.080513
# std    1.372022e+10   32833.858372
# min    1.101000e+07       1.000000
# 25%    2.106002e+07     563.000000
# 50%    8.140410e+08    1000.000000
# 75%    8.230400e+08    2361.500000
# max    8.731751e+10  659430.000000

# %%
df.plot(kind='bar')
# Out:
# <AxesSubplot:>
